# %%
import csv
import json
from collections import Counter 
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
import load_data

# %% [markdown]
# # Load all the data of authors and papers:

# %%
import os; os.chdir('/mnt/c/Users/maaik/Documents/thesis')
# Out:
# '/mnt/c/Users/maaik/Documents/thesis'

# %%
authors_file = "resources/evaluation/2020/corpus-subset-for-queries.authors.csv"
papers_file = "resources/evaluation/2020/corpus-subset-for-queries.papers.csv"
authors_papers_file = "resources/evaluation/2020/corpus-subset-for-queries.paper_authors.csv"
corpus_data_file = "resources/corpus/2020/corpus-subset-for-queries.jsonl"
training_data_file = 'resources/training/2020/TREC-Fair-Ranking-training-sample.json'

authors = load_data.load_authors(authors_file)
papers = load_data.load_papers(papers_file)
papers = load_data.load_papers_authors(authors_papers_file, papers)
papers = load_data.load_corpus(corpus_data_file, papers)
training_data = load_data.load_training_data(training_data_file)

# %% [markdown]
# # Create graph with citations

# %%
G_papers = nx.Graph()
G_authors = nx.Graph()
for key in papers.keys():
    for key2 in papers[key]['outCitations']:
        G_papers.add_edge(key, key2) 
    for key2 in papers[key]['inCitations']:
        G_papers.add_edge(key2, key) 
    if 'authors_order' not in papers[key]:
        papers[key]['authors_avg_citations'] = papers[key]['n_citations']
    else:
        for author1 in papers[key]['authors_order']:
            for author2 in papers[key]['authors_order']:
                if author1[0] != author2[0] and author2[0] != '' and author1[0] != '':
                    G_authors.add_edge(author1[0], author2[0]) 
        #print (papers[key]['authors_order'])
        papers[key]['authors_avg_citations'] = np.mean([int(authors[a[0]]['num_citations']) for a in papers[key]['authors_order'] if (a[0] in authors)])
        papers[key]['authors_avg_h_index'] = np.mean([int(authors[a[0]]['h_index']) for a in papers[key]['authors_order'] if (a[0] in authors)])
# Out:
# /home/pilmus/thesis/venv/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/pilmus/thesis/venv/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# # Some Stats

# %%
print ("Number of authors:", len(authors))
print ("Max papers:", max([int(a['num_papers']) for a in authors.values()]))
print ("Max citations:", max([int(a['num_citations']) for a in authors.values()]))
# Out:
# Number of authors: 31975
# Max papers: 10011
# Max citations: 223684

# %%
authors
# Out:
# {'50240353': {'corpus_author_id': '50240353',
#   'name': 'Badder Marzocchi',
#   'num_citations': '4653',
#   'num_papers': '522',
#   'i10': '102',
#   'h_index': '30',
#   'h_class': 'H'},
#  '26971991': {'corpus_author_id': '26971991',
#   'name': 'Patrick Fontana',
#   'num_citations': '133',
#   'num_papers': '72',
#   'i10': '4',
#   'h_index': '7',
#   'h_class': 'L'},
#  '5527266': {'corpus_author_id': '5527266',
#   'name': 'Firdevs Örnek',
#   'num_citations': '67',
#   'num_papers': '66',
#   'i10': '1',
#   'h_index': '5',
#   'h_class': 'L'},
#  '144886693': {'corpus_author_id': '144886693',
#   'name': 'Prashant Kumar Singh',
#   'num_citations': '3773',
#   'num_papers': '45',
#   'i10': '14',
#   'h_index': '14',
#   'h_class': 'H'},
#  '40552524': {'corpus_author_id': '40552524',
#   'name': 'Jacqueline Day',
#   'num_citations': '186',
#   'num_papers': '6',
#   'i10': '3',
#   'h_index': '5',
#   'h_class': 'L'},
#  '32761043': {'corpus_author_id': '32761043',
#   'name': 'Richard E. Petty',
#   'num_citations': '32092',
#   'num_papers': '431',
#   'i10': '247',
#   'h_index': '82',
#   'h_class': 'H'},
#  '1381968307': {'corpus_author_id': '1381968307',
#   'name': 'Lawrence A. Wade',
#   'num_citations': '3570',
#   'num_papers': '100',
#   'i10': '30',
#   'h_index': '20',
#   'h_class': 'H'},
#  '83256990': {'corpus_author_id': '83256990',
#   'name': 'Tawfik Ahmed Muthafer Khoja',
#   'num_citations': '3115',
#   'num_papers': '11',
#   'i10': '5',
#   'h_index': '7',
#   'h_class': 'L'},
#  '145915159': {'corpus_author_id': '145915159',
#   'name': 'Ricardo Orozco',
#   'num_citations': '709',
#   'num_papers': '7',
#   'i10': '5',
#   'h_index': '6',
#   'h_class': 'L'},
#  '144869300': {'corpus_author_id': '144869300',
#   'name': 'Jianxing He',
#   'num_citations': '2579',
#   'num_papers': '289',
#   'i10': '64',
#   'h_index': '24',
#   'h_class': 'H'},
#  '32861674': {'corpus_author_id': '32861674',
#   'name': 'Yana C Vierboom',
#   'num_citations': '32',
#   'num_papers': '12',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '145187595': {'corpus_author_id': '145187595',
#   'name': 'Hang Wong',
#   'num_citations': '1758',
#   'num_papers': '159',
#   'i10': '45',
#   'h_index': '26',
#   'h_class': 'H'},
#  '30087560': {'corpus_author_id': '30087560',
#   'name': 'Xiao-Shuang Zheng',
#   'num_citations': '1248',
#   'num_papers': '7',
#   'i10': '5',
#   'h_index': '5',
#   'h_class': 'L'},
#  '144198585': {'corpus_author_id': '144198585',
#   'name': 'Marilyn Tremaine',
#   'num_citations': '1750',
#   'num_papers': '98',
#   'i10': '30',
#   'h_index': '22',
#   'h_class': 'H'},
#  '31590004': {'corpus_author_id': '31590004',
#   'name': 'Sharon Robey',
#   'num_citations': '50',
#   'num_papers': '3',
#   'i10': '2',
#   'h_index': '2',
#   'h_class': 'L'},
#  '1759010': {'corpus_author_id': '1759010',
#   'name': 'Eric A. Brewer',
#   'num_citations': '13872',
#   'num_papers': '240',
#   'i10': '137',
#   'h_index': '60',
#   'h_class': 'H'},
#  '36123378': {'corpus_author_id': '36123378',
#   'name': 'Edmilson José Tonelli Manganote',
#   'num_citations': '742',
#   'num_papers': '303',
#   'i10': '25',
#   'h_index': '16',
#   'h_class': 'H'},
#  '143825130': {'corpus_author_id': '143825130',
#   'name': 'Katherine L. Byrne',
#   'num_citations': '1',
#   'num_papers': '14',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '78638375': {'corpus_author_id': '78638375',
#   'name': 'Heinz Schuler',
#   'num_citations': '853',
#   'num_papers': '122',
#   'i10': '20',
#   'h_index': '14',
#   'h_class': 'H'},
#  '46274872': {'corpus_author_id': '46274872',
#   'name': 'Charles Curtis Eriksen',
#   'num_citations': '2447',
#   'num_papers': '92',
#   'i10': '37',
#   'h_index': '22',
#   'h_class': 'H'},
#  '8054894': {'corpus_author_id': '8054894',
#   'name': 'Emil R. Rodolfa',
#   'num_citations': '963',
#   'num_papers': '61',
#   'i10': '25',
#   'h_index': '18',
#   'h_class': 'H'},
#  '147075306': {'corpus_author_id': '147075306',
#   'name': 'Jing Gu',
#   'num_citations': '48',
#   'num_papers': '31',
#   'i10': '1',
#   'h_index': '5',
#   'h_class': 'L'},
#  '1403373208': {'corpus_author_id': '1403373208',
#   'name': 'Rinat Armony-Sivan',
#   'num_citations': '383',
#   'num_papers': '14',
#   'i10': '8',
#   'h_index': '8',
#   'h_class': 'L'},
#  '1423021547': {'corpus_author_id': '1423021547',
#   'name': 'Michele Gold-Morgan',
#   'num_citations': '7',
#   'num_papers': '4',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '37662686': {'corpus_author_id': '37662686',
#   'name': 'Tetsuya Tsurumi',
#   'num_citations': '318',
#   'num_papers': '58',
#   'i10': '6',
#   'h_index': '8',
#   'h_class': 'L'},
#  '118208556': {'corpus_author_id': '118208556',
#   'name': 'Zsuzsanna Ajtony',
#   'num_citations': '10',
#   'num_papers': '17',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '4351220': {'corpus_author_id': '4351220',
#   'name': 'Mathieu Remazeilles',
#   'num_citations': '5159',
#   'num_papers': '239',
#   'i10': '60',
#   'h_index': '29',
#   'h_class': 'H'},
#  '101281903': {'corpus_author_id': '101281903',
#   'name': 'Martin Kirakosyan',
#   'num_citations': '1486',
#   'num_papers': '235',
#   'i10': '32',
#   'h_index': '18',
#   'h_class': 'H'},
#  '114973370': {'corpus_author_id': '114973370',
#   'name': 'N A Levi',
#   'num_citations': '1339',
#   'num_papers': '5',
#   'i10': '5',
#   'h_index': '5',
#   'h_class': 'L'},
#  '93992495': {'corpus_author_id': '93992495',
#   'name': 'C. C. Downie',
#   'num_citations': '0',
#   'num_papers': '3',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '144733293': {'corpus_author_id': '144733293',
#   'name': 'Roger Fletcher',
#   'num_citations': '8131',
#   'num_papers': '134',
#   'i10': '49',
#   'h_index': '32',
#   'h_class': 'H'},
#  '77665848': {'corpus_author_id': '77665848',
#   'name': 'Timothy M. Uyeki',
#   'num_citations': '743',
#   'num_papers': '14',
#   'i10': '7',
#   'h_index': '7',
#   'h_class': 'L'},
#  '3828009': {'corpus_author_id': '3828009',
#   'name': 'Miguel M. Unzueta',
#   'num_citations': '607',
#   'num_papers': '42',
#   'i10': '17',
#   'h_index': '14',
#   'h_class': 'H'},
#  '48157836': {'corpus_author_id': '48157836',
#   'name': 'Ivaylo P. Ivanov',
#   'num_citations': '111',
#   'num_papers': '37',
#   'i10': '2',
#   'h_index': '5',
#   'h_class': 'L'},
#  '72188475': {'corpus_author_id': '72188475',
#   'name': 'Zi-wei Hu',
#   'num_citations': '101',
#   'num_papers': '7',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '102309150': {'corpus_author_id': '102309150',
#   'name': 'Hengne Li',
#   'num_citations': '3554',
#   'num_papers': '408',
#   'i10': '89',
#   'h_index': '25',
#   'h_class': 'H'},
#  '3860387': {'corpus_author_id': '3860387',
#   'name': 'V. Tcherniatine',
#   'num_citations': '1912',
#   'num_papers': '38',
#   'i10': '14',
#   'h_index': '12',
#   'h_class': 'H'},
#  '49228525': {'corpus_author_id': '49228525',
#   'name': 'Meng Xiao',
#   'num_citations': '6934',
#   'num_papers': '512',
#   'i10': '120',
#   'h_index': '33',
#   'h_class': 'H'},
#  '1678328': {'corpus_author_id': '1678328',
#   'name': 'Wolfgang Prinz',
#   'num_citations': '1513',
#   'num_papers': '89',
#   'i10': '22',
#   'h_index': '19',
#   'h_class': 'H'},
#  '144434734': {'corpus_author_id': '144434734',
#   'name': 'Matti Hämäläinen',
#   'num_citations': '8521',
#   'num_papers': '305',
#   'i10': '90',
#   'h_index': '40',
#   'h_class': 'H'},
#  '38774434': {'corpus_author_id': '38774434',
#   'name': 'Seung-Tae Ko',
#   'num_citations': '370',
#   'num_papers': '26',
#   'i10': '5',
#   'h_index': '7',
#   'h_class': 'L'},
#  '144874832': {'corpus_author_id': '144874832',
#   'name': 'Mugen Peng',
#   'num_citations': '6310',
#   'num_papers': '444',
#   'i10': '103',
#   'h_index': '36',
#   'h_class': 'H'},
#  '2952140': {'corpus_author_id': '2952140',
#   'name': 'Jiansen Li',
#   'num_citations': '130',
#   'num_papers': '15',
#   'i10': '2',
#   'h_index': '6',
#   'h_class': 'L'},
#  '4734872': {'corpus_author_id': '4734872',
#   'name': 'Diane Whitmore Schanzenbach',
#   'num_citations': '1117',
#   'num_papers': '38',
#   'i10': '11',
#   'h_index': '11',
#   'h_class': 'H'},
#  '100670349': {'corpus_author_id': '100670349',
#   'name': 'Mia Tosi',
#   'num_citations': '6034',
#   'num_papers': '569',
#   'i10': '130',
#   'h_index': '35',
#   'h_class': 'H'},
#  '1390132140': {'corpus_author_id': '1390132140',
#   'name': 'Youssef Ibrahim Haggag',
#   'num_citations': '0',
#   'num_papers': '1',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '144702469': {'corpus_author_id': '144702469',
#   'name': 'Lei Zheng',
#   'num_citations': '1600',
#   'num_papers': '162',
#   'i10': '37',
#   'h_index': '18',
#   'h_class': 'H'},
#  '35162690': {'corpus_author_id': '35162690',
#   'name': 'Simon Seif',
#   'num_citations': '43',
#   'num_papers': '6',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '103821210': {'corpus_author_id': '103821210',
#   'name': 'Abdunnur S. Suleiman',
#   'num_citations': '2',
#   'num_papers': '2',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '9211244': {'corpus_author_id': '9211244',
#   'name': 'Chung-Kwang Chou',
#   'num_citations': '320',
#   'num_papers': '35',
#   'i10': '13',
#   'h_index': '12',
#   'h_class': 'H'},
#  '145864915': {'corpus_author_id': '145864915',
#   'name': 'Juan Colmenares',
#   'num_citations': '289',
#   'num_papers': '32',
#   'i10': '10',
#   'h_index': '10',
#   'h_class': 'H'},
#  '98212058': {'corpus_author_id': '98212058',
#   'name': 'Winnie Daamen',
#   'num_citations': '1817',
#   'num_papers': '188',
#   'i10': '50',
#   'h_index': '21',
#   'h_class': 'H'},
#  '33483349': {'corpus_author_id': '33483349',
#   'name': 'Ralf Moos',
#   'num_citations': '1935',
#   'num_papers': '747',
#   'i10': '60',
#   'h_index': '19',
#   'h_class': 'H'},
#  '1767402': {'corpus_author_id': '1767402',
#   'name': 'Xiaolan Zhang',
#   'num_citations': '10344',
#   'num_papers': '91',
#   'i10': '52',
#   'h_index': '38',
#   'h_class': 'H'},
#  '37471458': {'corpus_author_id': '37471458',
#   'name': 'Audrey L Jenkins',
#   'num_citations': '38',
#   'num_papers': '3',
#   'i10': '2',
#   'h_index': '2',
#   'h_class': 'L'},
#  '144239558': {'corpus_author_id': '144239558',
#   'name': 'Ming Wei',
#   'num_citations': '1347',
#   'num_papers': '455',
#   'i10': '29',
#   'h_index': '15',
#   'h_class': 'H'},
#  '31682694': {'corpus_author_id': '31682694',
#   'name': 'Michael W Lu',
#   'num_citations': '1221',
#   'num_papers': '10',
#   'i10': '5',
#   'h_index': '6',
#   'h_class': 'L'},
#  '33303951': {'corpus_author_id': '33303951',
#   'name': 'Darlene A Weston',
#   'num_citations': '413',
#   'num_papers': '36',
#   'i10': '11',
#   'h_index': '11',
#   'h_class': 'H'},
#  '47437200': {'corpus_author_id': '47437200',
#   'name': 'Kuresh A. Youdim',
#   'num_citations': '1995',
#   'num_papers': '21',
#   'i10': '19',
#   'h_index': '19',
#   'h_class': 'H'},
#  '39587245': {'corpus_author_id': '39587245',
#   'name': 'Brian S. Lowery',
#   'num_citations': '1240',
#   'num_papers': '42',
#   'i10': '21',
#   'h_index': '17',
#   'h_class': 'H'},
#  '4375836': {'corpus_author_id': '4375836',
#   'name': 'Susan L Averett',
#   'num_citations': '1197',
#   'num_papers': '103',
#   'i10': '30',
#   'h_index': '16',
#   'h_class': 'H'},
#  '2487014': {'corpus_author_id': '2487014',
#   'name': 'Yu Feng',
#   'num_citations': '3158',
#   'num_papers': '749',
#   'i10': '69',
#   'h_index': '21',
#   'h_class': 'H'},
#  '1970566': {'corpus_author_id': '1970566',
#   'name': 'Christian Rössel',
#   'num_citations': '777',
#   'num_papers': '16',
#   'i10': '9',
#   'h_index': '9',
#   'h_class': 'L'},
#  '114360953': {'corpus_author_id': '114360953',
#   'name': 'Mo Alkaysi',
#   'num_citations': '37',
#   'num_papers': '4',
#   'i10': '1',
#   'h_index': '4',
#   'h_class': 'L'},
#  '2274382': {'corpus_author_id': '2274382',
#   'name': 'Lara A. Boyd',
#   'num_citations': '4698',
#   'num_papers': '213',
#   'i10': '101',
#   'h_index': '39',
#   'h_class': 'H'},
#  '91633211': {'corpus_author_id': '91633211',
#   'name': 'Kenneth Pearlman',
#   'num_citations': '895',
#   'num_papers': '37',
#   'i10': '13',
#   'h_index': '12',
#   'h_class': 'H'},
#  '50660128': {'corpus_author_id': '50660128',
#   'name': 'Stuart G. Coles',
#   'num_citations': '509',
#   'num_papers': '11',
#   'i10': '6',
#   'h_index': '7',
#   'h_class': 'L'},
#  '2317658': {'corpus_author_id': '2317658',
#   'name': 'Rainer Bartoldus',
#   'num_citations': '12952',
#   'num_papers': '1124',
#   'i10': '239',
#   'h_index': '49',
#   'h_class': 'H'},
#  '50458064': {'corpus_author_id': '50458064',
#   'name': 'Sravanthi Reddy',
#   'num_citations': '297',
#   'num_papers': '42',
#   'i10': '13',
#   'h_index': '12',
#   'h_class': 'H'},
#  '1410936175': {'corpus_author_id': '1410936175',
#   'name': 'Li Li-li',
#   'num_citations': '6',
#   'num_papers': '62',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '33230432': {'corpus_author_id': '33230432',
#   'name': 'Pei-Yu Chiang',
#   'num_citations': '41',
#   'num_papers': '15',
#   'i10': '2',
#   'h_index': '3',
#   'h_class': 'L'},
#  '145437324': {'corpus_author_id': '145437324',
#   'name': 'A. J. Leonard',
#   'num_citations': '216',
#   'num_papers': '10',
#   'i10': '5',
#   'h_index': '5',
#   'h_class': 'L'},
#  '50196944': {'corpus_author_id': '50196944',
#   'name': 'Judy Hoffman',
#   'num_citations': '7884',
#   'num_papers': '60',
#   'i10': '39',
#   'h_index': '29',
#   'h_class': 'H'},
#  '4803385': {'corpus_author_id': '4803385',
#   'name': 'Christine Purdon',
#   'num_citations': '1747',
#   'num_papers': '76',
#   'i10': '29',
#   'h_index': '20',
#   'h_class': 'H'},
#  '49177502': {'corpus_author_id': '49177502',
#   'name': 'Haiping Chen',
#   'num_citations': '256',
#   'num_papers': '13',
#   'i10': '3',
#   'h_index': '4',
#   'h_class': 'L'},
#  '144155295': {'corpus_author_id': '144155295',
#   'name': 'Tyson Michael Roberts',
#   'num_citations': '28',
#   'num_papers': '14',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '1604779278': {'corpus_author_id': '1604779278',
#   'name': 'She Jiatong',
#   'num_citations': '2',
#   'num_papers': '1',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '144970557': {'corpus_author_id': '144970557',
#   'name': 'Helmut G. Alt',
#   'num_citations': '247',
#   'num_papers': '441',
#   'i10': '3',
#   'h_index': '8',
#   'h_class': 'L'},
#  '116841742': {'corpus_author_id': '116841742',
#   'name': 'Antonis Agapitos',
#   'num_citations': '4055',
#   'num_papers': '431',
#   'i10': '87',
#   'h_index': '27',
#   'h_class': 'H'},
#  '39238359': {'corpus_author_id': '39238359',
#   'name': 'Louise Stoll',
#   'num_citations': '4419',
#   'num_papers': '209',
#   'i10': '55',
#   'h_index': '26',
#   'h_class': 'H'},
#  '3593895': {'corpus_author_id': '3593895',
#   'name': 'Rudolf P. Bohm',
#   'num_citations': '798',
#   'num_papers': '67',
#   'i10': '23',
#   'h_index': '15',
#   'h_class': 'H'},
#  '39749192': {'corpus_author_id': '39749192',
#   'name': 'Kevin Meinert',
#   'num_citations': '402',
#   'num_papers': '10',
#   'i10': '2',
#   'h_index': '5',
#   'h_class': 'L'},
#  '145994535': {'corpus_author_id': '145994535',
#   'name': 'Beniko Mason',
#   'num_citations': '360',
#   'num_papers': '18',
#   'i10': '5',
#   'h_index': '6',
#   'h_class': 'L'},
#  '122112922': {'corpus_author_id': '122112922',
#   'name': 'Xiao-jun Wu',
#   'num_citations': '87',
#   'num_papers': '14',
#   'i10': '3',
#   'h_index': '3',
#   'h_class': 'L'},
#  '14147626': {'corpus_author_id': '14147626',
#   'name': 'Majid Haj Abbasi',
#   'num_citations': '10',
#   'num_papers': '1',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '6348621': {'corpus_author_id': '6348621',
#   'name': 'Matthew M Heeney',
#   'num_citations': '1713',
#   'num_papers': '111',
#   'i10': '38',
#   'h_index': '21',
#   'h_class': 'H'},
#  '6090450': {'corpus_author_id': '6090450',
#   'name': 'Patrick T Mather',
#   'num_citations': '2538',
#   'num_papers': '244',
#   'i10': '66',
#   'h_index': '25',
#   'h_class': 'H'},
#  '2123865': {'corpus_author_id': '2123865',
#   'name': 'Frederick Tung',
#   'num_citations': '501',
#   'num_papers': '63',
#   'i10': '19',
#   'h_index': '13',
#   'h_class': 'H'},
#  '2008655': {'corpus_author_id': '2008655',
#   'name': 'Catrin Misselhorn',
#   'num_citations': '76',
#   'num_papers': '41',
#   'i10': '2',
#   'h_index': '4',
#   'h_class': 'L'},
#  '3696510': {'corpus_author_id': '3696510',
#   'name': 'Dana K. Andersen',
#   'num_citations': '4492',
#   'num_papers': '185',
#   'i10': '75',
#   'h_index': '29',
#   'h_class': 'H'},
#  '152397486': {'corpus_author_id': '152397486',
#   'name': 'Anna Colaleo',
#   'num_citations': '7017',
#   'num_papers': '831',
#   'i10': '152',
#   'h_index': '37',
#   'h_class': 'H'},
#  '35146658': {'corpus_author_id': '35146658',
#   'name': 'Kristin L. Kirkpatrick',
#   'num_citations': '1187',
#   'num_papers': '8',
#   'i10': '4',
#   'h_index': '4',
#   'h_class': 'L'},
#  '144713524': {'corpus_author_id': '144713524',
#   'name': 'Andrew Morrison',
#   'num_citations': '752',
#   'num_papers': '83',
#   'i10': '20',
#   'h_index': '15',
#   'h_class': 'H'},
#  '145712120': {'corpus_author_id': '145712120',
#   'name': 'Chia-Cheng Chou',
#   'num_citations': '731',
#   'num_papers': '67',
#   'i10': '21',
#   'h_index': '15',
#   'h_class': 'H'},
#  '46336310': {'corpus_author_id': '46336310',
#   'name': 'Edgar R. Black',
#   'num_citations': '790',
#   'num_papers': '17',
#   'i10': '7',
#   'h_index': '8',
#   'h_class': 'L'},
#  '1981455': {'corpus_author_id': '1981455',
#   'name': 'Cheikh Mbow',
#   'num_citations': '2329',
#   'num_papers': '77',
#   'i10': '38',
#   'h_index': '24',
#   'h_class': 'H'},
#  '104454742': {'corpus_author_id': '104454742',
#   'name': 'Alice Cocoros',
#   'num_citations': '1791',
#   'num_papers': '366',
#   'i10': '53',
#   'h_index': '21',
#   'h_class': 'H'},
#  '1699037': {'corpus_author_id': '1699037',
#   'name': 'Bin Wu',
#   'num_citations': '2901',
#   'num_papers': '351',
#   'i10': '78',
#   'h_index': '27',
#   'h_class': 'H'},
#  '145931620': {'corpus_author_id': '145931620',
#   'name': 'H. K. Lin',
#   'num_citations': '140',
#   'num_papers': '10',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '116376080': {'corpus_author_id': '116376080',
#   'name': 'Manchester City Art Gallery',
#   'num_citations': '21',
#   'num_papers': '15',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '144848951': {'corpus_author_id': '144848951',
#   'name': 'Joseph Bonneau',
#   'num_citations': '4542',
#   'num_papers': '104',
#   'i10': '53',
#   'h_index': '31',
#   'h_class': 'H'},
#  '144248892': {'corpus_author_id': '144248892',
#   'name': 'Charles Spence',
#   'num_citations': '5823',
#   'num_papers': '466',
#   'i10': '139',
#   'h_index': '41',
#   'h_class': 'H'},
#  '11541898': {'corpus_author_id': '11541898',
#   'name': 'Mika Ohta',
#   'num_citations': '136',
#   'num_papers': '27',
#   'i10': '4',
#   'h_index': '6',
#   'h_class': 'L'},
#  '51364807': {'corpus_author_id': '51364807',
#   'name': 'Jesse Wagner',
#   'num_citations': '81',
#   'num_papers': '35',
#   'i10': '2',
#   'h_index': '3',
#   'h_class': 'L'},
#  '49543384': {'corpus_author_id': '49543384',
#   'name': 'Xiao Lin Liu',
#   'num_citations': '1490',
#   'num_papers': '34',
#   'i10': '13',
#   'h_index': '12',
#   'h_class': 'H'},
#  '46997370': {'corpus_author_id': '46997370',
#   'name': 'Ronald E. Goldsmith',
#   'num_citations': '7272',
#   'num_papers': '232',
#   'i10': '100',
#   'h_index': '43',
#   'h_class': 'H'},
#  '3051132': {'corpus_author_id': '3051132',
#   'name': 'Guang-Jie Ren',
#   'num_citations': '248',
#   'num_papers': '25',
#   'i10': '9',
#   'h_index': '9',
#   'h_class': 'L'},
#  '145443952': {'corpus_author_id': '145443952',
#   'name': 'Giovanni Chiefari',
#   'num_citations': '8309',
#   'num_papers': '382',
#   'i10': '118',
#   'h_index': '40',
#   'h_class': 'H'},
#  '116035738': {'corpus_author_id': '116035738',
#   'name': 'M. Edwin Agwu',
#   'num_citations': '112',
#   'num_papers': '21',
#   'i10': '5',
#   'h_index': '7',
#   'h_class': 'L'},
#  '4063044': {'corpus_author_id': '4063044',
#   'name': 'John S. Carson',
#   'num_citations': '2917',
#   'num_papers': '53',
#   'i10': '12',
#   'h_index': '12',
#   'h_class': 'H'},
#  '11951365': {'corpus_author_id': '11951365',
#   'name': 'Zeshi Li',
#   'num_citations': '89',
#   'num_papers': '7',
#   'i10': '3',
#   'h_index': '6',
#   'h_class': 'L'},
#  '7282805': {'corpus_author_id': '7282805',
#   'name': 'Stephen G. Waller',
#   'num_citations': '3729',
#   'num_papers': '58',
#   'i10': '10',
#   'h_index': '10',
#   'h_class': 'H'},
#  '1396190563': {'corpus_author_id': '1396190563',
#   'name': 'Roberto Rodríguez-Roisin',
#   'num_citations': '13078',
#   'num_papers': '185',
#   'i10': '78',
#   'h_index': '35',
#   'h_class': 'H'},
#  '34384210': {'corpus_author_id': '34384210',
#   'name': 'Samir S Soneji',
#   'num_citations': '7558',
#   'num_papers': '94',
#   'i10': '42',
#   'h_index': '26',
#   'h_class': 'H'},
#  '49130504': {'corpus_author_id': '49130504',
#   'name': 'Claire E. Adams',
#   'num_citations': '1246',
#   'num_papers': '38',
#   'i10': '16',
#   'h_index': '12',
#   'h_class': 'H'},
#  '122484563': {'corpus_author_id': '122484563',
#   'name': 'Adeghe Raph',
#   'num_citations': '1',
#   'num_papers': '2',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '144727976': {'corpus_author_id': '144727976',
#   'name': 'Mahmoud Ismail',
#   'num_citations': '566',
#   'num_papers': '74',
#   'i10': '8',
#   'h_index': '10',
#   'h_class': 'H'},
#  '6078103': {'corpus_author_id': '6078103',
#   'name': 'G. D. Imes',
#   'num_citations': '152',
#   'num_papers': '27',
#   'i10': '6',
#   'h_index': '8',
#   'h_class': 'L'},
#  '153495804': {'corpus_author_id': '153495804',
#   'name': 'Juan Ignacio Iturrioz Sánchez',
#   'num_citations': '85',
#   'num_papers': '18',
#   'i10': '2',
#   'h_index': '3',
#   'h_class': 'L'},
#  '91492918': {'corpus_author_id': '91492918',
#   'name': 'Berta Bekti Retnawati',
#   'num_citations': '11',
#   'num_papers': '23',
#   'i10': '0',
#   'h_index': '3',
#   'h_class': 'L'},
#  '118090841': {'corpus_author_id': '118090841',
#   'name': 'Abdullah Fawzi Khorshid',
#   'num_citations': '8',
#   'num_papers': '3',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '6173041': {'corpus_author_id': '6173041',
#   'name': 'David Romero Abad',
#   'num_citations': '1991',
#   'num_papers': '266',
#   'i10': '67',
#   'h_index': '22',
#   'h_class': 'H'},
#  '48062912': {'corpus_author_id': '48062912',
#   'name': 'Giovanni Crespi',
#   'num_citations': '65',
#   'num_papers': '12',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '145174228': {'corpus_author_id': '145174228',
#   'name': 'Jodi Forlizzi',
#   'num_citations': '10863',
#   'num_papers': '230',
#   'i10': '127',
#   'h_index': '55',
#   'h_class': 'H'},
#  '6456535': {'corpus_author_id': '6456535',
#   'name': 'Takehiko Takatori',
#   'num_citations': '862',
#   'num_papers': '191',
#   'i10': '24',
#   'h_index': '13',
#   'h_class': 'H'},
#  '2407129': {'corpus_author_id': '2407129',
#   'name': 'Inge Geyskens',
#   'num_citations': '2847',
#   'num_papers': '58',
#   'i10': '21',
#   'h_index': '17',
#   'h_class': 'H'},
#  '92407861': {'corpus_author_id': '92407861',
#   'name': 'John L. Campbell',
#   'num_citations': '3270',
#   'num_papers': '211',
#   'i10': '42',
#   'h_index': '21',
#   'h_class': 'H'},
#  '145873345': {'corpus_author_id': '145873345',
#   'name': 'Rodney D. Phoenix',
#   'num_citations': '275',
#   'num_papers': '29',
#   'i10': '10',
#   'h_index': '10',
#   'h_class': 'H'},
#  '47540993': {'corpus_author_id': '47540993',
#   'name': 'Masaaki Kimura',
#   'num_citations': '2265',
#   'num_papers': '222',
#   'i10': '15',
#   'h_index': '14',
#   'h_class': 'H'},
#  '118952383': {'corpus_author_id': '118952383',
#   'name': 'David Feeny',
#   'num_citations': '1547',
#   'num_papers': '43',
#   'i10': '8',
#   'h_index': '9',
#   'h_class': 'L'},
#  '7385635': {'corpus_author_id': '7385635',
#   'name': 'Xiaobing Deng',
#   'num_citations': '1279',
#   'num_papers': '39',
#   'i10': '20',
#   'h_index': '16',
#   'h_class': 'H'},
#  '1491090296': {'corpus_author_id': '1491090296',
#   'name': 'Boxi Liu',
#   'num_citations': '1152',
#   'num_papers': '1',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '143786001': {'corpus_author_id': '143786001',
#   'name': 'Viswanathan Mohan',
#   'num_citations': '5839',
#   'num_papers': '64',
#   'i10': '33',
#   'h_index': '22',
#   'h_class': 'H'},
#  '48058907': {'corpus_author_id': '48058907',
#   'name': 'Iddo Friedberg',
#   'num_citations': '2577',
#   'num_papers': '47',
#   'i10': '15',
#   'h_index': '13',
#   'h_class': 'H'},
#  '48124116': {'corpus_author_id': '48124116',
#   'name': 'Brian A. Mcnulty',
#   'num_citations': '966',
#   'num_papers': '18',
#   'i10': '4',
#   'h_index': '6',
#   'h_class': 'L'},
#  '47369824': {'corpus_author_id': '47369824',
#   'name': 'Jody Heymann',
#   'num_citations': '841',
#   'num_papers': '111',
#   'i10': '24',
#   'h_index': '17',
#   'h_class': 'H'},
#  '79109426': {'corpus_author_id': '79109426',
#   'name': 'Alison J. Ross',
#   'num_citations': '447',
#   'num_papers': '41',
#   'i10': '8',
#   'h_index': '9',
#   'h_class': 'L'},
#  '5667927': {'corpus_author_id': '5667927',
#   'name': 'Tomas G M Hökfelt',
#   'num_citations': '28089',
#   'num_papers': '1234',
#   'i10': '656',
#   'h_index': '74',
#   'h_class': 'H'},
#  '145324163': {'corpus_author_id': '145324163',
#   'name': 'Paul McNamee',
#   'num_citations': '3961',
#   'num_papers': '246',
#   'i10': '93',
#   'h_index': '35',
#   'h_class': 'H'},
#  '40611236': {'corpus_author_id': '40611236',
#   'name': 'Alison Dixon',
#   'num_citations': '7',
#   'num_papers': '5',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '2181970': {'corpus_author_id': '2181970',
#   'name': 'Yasumasa Ohyagi',
#   'num_citations': '1198',
#   'num_papers': '150',
#   'i10': '37',
#   'h_index': '19',
#   'h_class': 'H'},
#  '48670684': {'corpus_author_id': '48670684',
#   'name': 'Xiaotian Xu',
#   'num_citations': '104',
#   'num_papers': '22',
#   'i10': '2',
#   'h_index': '3',
#   'h_class': 'L'},
#  '1637350987': {'corpus_author_id': '1637350987',
#   'name': 'Rebecca Fineman',
#   'num_citations': '62',
#   'num_papers': '1',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '2535887': {'corpus_author_id': '2535887',
#   'name': 'Bryan Seybold',
#   'num_citations': '881',
#   'num_papers': '16',
#   'i10': '8',
#   'h_index': '8',
#   'h_class': 'L'},
#  '121312920': {'corpus_author_id': '121312920',
#   'name': 'Mary Fairchok',
#   'num_citations': '37',
#   'num_papers': '4',
#   'i10': '2',
#   'h_index': '3',
#   'h_class': 'L'},
#  '8100157': {'corpus_author_id': '8100157',
#   'name': 'Bahaa I. Kazem',
#   'num_citations': '32',
#   'num_papers': '5',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '8456679': {'corpus_author_id': '8456679',
#   'name': 'Athina Thanou',
#   'num_citations': '41',
#   'num_papers': '8',
#   'i10': '2',
#   'h_index': '5',
#   'h_class': 'L'},
#  '1414027076': {'corpus_author_id': '1414027076',
#   'name': 'Juan A. Garcia-Manrique',
#   'num_citations': '44',
#   'num_papers': '18',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '6929575': {'corpus_author_id': '6929575',
#   'name': 'Hossein Moayedi',
#   'num_citations': '819',
#   'num_papers': '121',
#   'i10': '26',
#   'h_index': '15',
#   'h_class': 'H'},
#  '10142329': {'corpus_author_id': '10142329',
#   'name': 'Gary Kochert',
#   'num_citations': '3189',
#   'num_papers': '91',
#   'i10': '49',
#   'h_index': '29',
#   'h_class': 'H'},
#  '144901480': {'corpus_author_id': '144901480',
#   'name': 'Mareva Foster',
#   'num_citations': '723',
#   'num_papers': '14',
#   'i10': '6',
#   'h_index': '8',
#   'h_class': 'L'},
#  '1399486062': {'corpus_author_id': '1399486062',
#   'name': 'Renate Klempien-Hinrichs',
#   'num_citations': '84',
#   'num_papers': '27',
#   'i10': '2',
#   'h_index': '6',
#   'h_class': 'L'},
#  '6715154': {'corpus_author_id': '6715154',
#   'name': 'Kunihiro Ohta',
#   'num_citations': '2442',
#   'num_papers': '164',
#   'i10': '60',
#   'h_index': '27',
#   'h_class': 'H'},
#  '80574665': {'corpus_author_id': '80574665',
#   'name': 'Can Deniz Köksal',
#   'num_citations': '82',
#   'num_papers': '15',
#   'i10': '2',
#   'h_index': '5',
#   'h_class': 'L'},
#  '144988716': {'corpus_author_id': '144988716',
#   'name': 'Rongxing Lu',
#   'num_citations': '10082',
#   'num_papers': '337',
#   'i10': '159',
#   'h_index': '51',
#   'h_class': 'H'},
#  '3985879': {'corpus_author_id': '3985879',
#   'name': 'Yanchen Zhou',
#   'num_citations': '359',
#   'num_papers': '24',
#   'i10': '11',
#   'h_index': '11',
#   'h_class': 'H'},
#  '1422312353': {'corpus_author_id': '1422312353',
#   'name': 'Kjetill Høydal',
#   'num_citations': '579',
#   'num_papers': '1',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '34958344': {'corpus_author_id': '34958344',
#   'name': 'Aya Yanagawa',
#   'num_citations': '311',
#   'num_papers': '24',
#   'i10': '10',
#   'h_index': '10',
#   'h_class': 'H'},
#  '6748997': {'corpus_author_id': '6748997',
#   'name': 'Frank Chlebana',
#   'num_citations': '10552',
#   'num_papers': '1105',
#   'i10': '184',
#   'h_index': '39',
#   'h_class': 'H'},
#  '51511078': {'corpus_author_id': '51511078',
#   'name': 'Doug Reid',
#   'num_citations': '136',
#   'num_papers': '36',
#   'i10': '5',
#   'h_index': '7',
#   'h_class': 'L'},
#  '100773607': {'corpus_author_id': '100773607',
#   'name': '罗时睿',
#   'num_citations': '0',
#   'num_papers': '4',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '143855206': {'corpus_author_id': '143855206',
#   'name': 'Charles Thomas Eagle',
#   'num_citations': '1204',
#   'num_papers': '26',
#   'i10': '3',
#   'h_index': '6',
#   'h_class': 'L'},
#  '144719934': {'corpus_author_id': '144719934',
#   'name': 'Mark Hills',
#   'num_citations': '387',
#   'num_papers': '51',
#   'i10': '17',
#   'h_index': '13',
#   'h_class': 'H'},
#  '10025541': {'corpus_author_id': '10025541',
#   'name': 'Patricia Marchak',
#   'num_citations': '866',
#   'num_papers': '32',
#   'i10': '5',
#   'h_index': '7',
#   'h_class': 'L'},
#  '4263752': {'corpus_author_id': '4263752',
#   'name': 'Graham A. Tipples',
#   'num_citations': '2737',
#   'num_papers': '84',
#   'i10': '37',
#   'h_index': '23',
#   'h_class': 'H'},
#  '3487593': {'corpus_author_id': '3487593',
#   'name': 'Lilian N. Dindo',
#   'num_citations': '521',
#   'num_papers': '57',
#   'i10': '11',
#   'h_index': '11',
#   'h_class': 'H'},
#  '122822483': {'corpus_author_id': '122822483',
#   'name': 'Diego Mart nez Gonz lez',
#   'num_citations': '0',
#   'num_papers': '1',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '150357254': {'corpus_author_id': '150357254',
#   'name': 'Zhi-hua Liu',
#   'num_citations': '99',
#   'num_papers': '15',
#   'i10': '2',
#   'h_index': '4',
#   'h_class': 'L'},
#  '96201562': {'corpus_author_id': '96201562',
#   'name': 'Lucia Silvestris',
#   'num_citations': '10270',
#   'num_papers': '900',
#   'i10': '155',
#   'h_index': '38',
#   'h_class': 'H'},
#  '49678782': {'corpus_author_id': '49678782',
#   'name': 'Ziyad Alharbi',
#   'num_citations': '83',
#   'num_papers': '9',
#   'i10': '2',
#   'h_index': '5',
#   'h_class': 'L'},
#  '3450459': {'corpus_author_id': '3450459',
#   'name': 'James S. Sims',
#   'num_citations': '449',
#   'num_papers': '54',
#   'i10': '7',
#   'h_index': '8',
#   'h_class': 'L'},
#  '46409511': {'corpus_author_id': '46409511',
#   'name': 'Paula Pezzuto',
#   'num_citations': '128',
#   'num_papers': '8',
#   'i10': '5',
#   'h_index': '5',
#   'h_class': 'L'},
#  '2657758': {'corpus_author_id': '2657758',
#   'name': 'Adam J. Kucharski',
#   'num_citations': '1632',
#   'num_papers': '160',
#   'i10': '43',
#   'h_index': '20',
#   'h_class': 'H'},
#  '1707871': {'corpus_author_id': '1707871',
#   'name': 'Wolfgang Ludwig Gross',
#   'num_citations': '10930',
#   'num_papers': '635',
#   'i10': '215',
#   'h_index': '53',
#   'h_class': 'H'},
#  '4729444': {'corpus_author_id': '4729444',
#   'name': 'Negar Morovatdar',
#   'num_citations': '43',
#   'num_papers': '39',
#   'i10': '0',
#   'h_index': '4',
#   'h_class': 'L'},
#  '35100474': {'corpus_author_id': '35100474',
#   'name': 'Noe L. Charbonneau',
#   'num_citations': '975',
#   'num_papers': '30',
#   'i10': '17',
#   'h_index': '15',
#   'h_class': 'H'},
#  '6198784': {'corpus_author_id': '6198784',
#   'name': 'Blazej Zbytek',
#   'num_citations': '1802',
#   'num_papers': '59',
#   'i10': '33',
#   'h_index': '24',
#   'h_class': 'H'},
#  '35432937': {'corpus_author_id': '35432937',
#   'name': 'Marco Toliman Lucchini',
#   'num_citations': '4546',
#   'num_papers': '504',
#   'i10': '105',
#   'h_index': '30',
#   'h_class': 'H'},
#  '70044746': {'corpus_author_id': '70044746',
#   'name': '穆宝忠',
#   'num_citations': '5',
#   'num_papers': '17',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '9106757': {'corpus_author_id': '9106757',
#   'name': 'Daniel A. Keim',
#   'num_citations': '18472',
#   'num_papers': '657',
#   'i10': '256',
#   'h_index': '56',
#   'h_class': 'H'},
#  '5745883': {'corpus_author_id': '5745883',
#   'name': 'Katsuyoshi Suzuki',
#   'num_citations': '494',
#   'num_papers': '71',
#   'i10': '8',
#   'h_index': '10',
#   'h_class': 'H'},
#  '113037738': {'corpus_author_id': '113037738',
#   'name': 'Peter Laugesen',
#   'num_citations': '214',
#   'num_papers': '11',
#   'i10': '2',
#   'h_index': '4',
#   'h_class': 'L'},
#  '6861292': {'corpus_author_id': '6861292',
#   'name': 'Liesi E. Hebert',
#   'num_citations': '12015',
#   'num_papers': '70',
#   'i10': '55',
#   'h_index': '40',
#   'h_class': 'H'},
#  '1769461': {'corpus_author_id': '1769461',
#   'name': 'Raghu Krishnapuram',
#   'num_citations': '6517',
#   'num_papers': '168',
#   'i10': '78',
#   'h_index': '37',
#   'h_class': 'H'},
#  '2729443': {'corpus_author_id': '2729443',
#   'name': 'Sebastian Raisch',
#   'num_citations': '1863',
#   'num_papers': '107',
#   'i10': '17',
#   'h_index': '13',
#   'h_class': 'H'},
#  '34634797': {'corpus_author_id': '34634797',
#   'name': 'Nobutaka Hattori',
#   'num_citations': '12146',
#   'num_papers': '711',
#   'i10': '226',
#   'h_index': '47',
#   'h_class': 'H'},
#  '143942869': {'corpus_author_id': '143942869',
#   'name': 'Dong Hyun Yoon',
#   'num_citations': '150',
#   'num_papers': '60',
#   'i10': '4',
#   'h_index': '8',
#   'h_class': 'L'},
#  '4925825': {'corpus_author_id': '4925825',
#   'name': 'Surendra S Ambegaokar',
#   'num_citations': '1073',
#   'num_papers': '7',
#   'i10': '5',
#   'h_index': '6',
#   'h_class': 'L'},
#  '32083583': {'corpus_author_id': '32083583',
#   'name': 'Juhani Kauppi',
#   'num_citations': '25',
#   'num_papers': '2',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '81996599': {'corpus_author_id': '81996599',
#   'name': 'Carolyn Kisner',
#   'num_citations': '631',
#   'num_papers': '9',
#   'i10': '2',
#   'h_index': '3',
#   'h_class': 'L'},
#  '6999264': {'corpus_author_id': '6999264',
#   'name': 'Hui-Ling Yen',
#   'num_citations': '2828',
#   'num_papers': '101',
#   'i10': '49',
#   'h_index': '26',
#   'h_class': 'H'},
#  '3072426': {'corpus_author_id': '3072426',
#   'name': 'David Fifield',
#   'num_citations': '424',
#   'num_papers': '23',
#   'i10': '8',
#   'h_index': '10',
#   'h_class': 'H'},
#  '80170558': {'corpus_author_id': '80170558',
#   'name': 'Sung-Pil Woo',
#   'num_citations': '18',
#   'num_papers': '4',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '4694086': {'corpus_author_id': '4694086',
#   'name': 'Grzegorz Bednarczuk',
#   'num_citations': '46',
#   'num_papers': '17',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '145872433': {'corpus_author_id': '145872433',
#   'name': 'Sally A. Miller',
#   'num_citations': '899',
#   'num_papers': '85',
#   'i10': '22',
#   'h_index': '16',
#   'h_class': 'H'},
#  '1408106943': {'corpus_author_id': '1408106943',
#   'name': 'Clemens Tesch-Römer',
#   'num_citations': '3516',
#   'num_papers': '87',
#   'i10': '6',
#   'h_index': '7',
#   'h_class': 'L'},
#  '9520362': {'corpus_author_id': '9520362',
#   'name': 'Amy K. Rines',
#   'num_citations': '259',
#   'num_papers': '25',
#   'i10': '7',
#   'h_index': '8',
#   'h_class': 'L'},
#  '1688764': {'corpus_author_id': '1688764',
#   'name': 'Peggy A. Ertmer',
#   'num_citations': '5266',
#   'num_papers': '73',
#   'i10': '33',
#   'h_index': '22',
#   'h_class': 'H'},
#  '144782176': {'corpus_author_id': '144782176',
#   'name': 'Baozhen Shan',
#   'num_citations': '2',
#   'num_papers': '6',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '4056872': {'corpus_author_id': '4056872',
#   'name': 'Riccardo Bartoletti',
#   'num_citations': '2147',
#   'num_papers': '308',
#   'i10': '62',
#   'h_index': '24',
#   'h_class': 'H'},
#  '144174385': {'corpus_author_id': '144174385',
#   'name': 'Javier Martín Blanco',
#   'num_citations': '1455',
#   'num_papers': '209',
#   'i10': '48',
#   'h_index': '22',
#   'h_class': 'H'},
#  '6046180': {'corpus_author_id': '6046180',
#   'name': 'Sophie Ismael',
#   'num_citations': '71',
#   'num_papers': '8',
#   'i10': '3',
#   'h_index': '4',
#   'h_class': 'L'},
#  '6394292': {'corpus_author_id': '6394292',
#   'name': 'Rashmikant V. Sudiwala',
#   'num_citations': '3854',
#   'num_papers': '145',
#   'i10': '39',
#   'h_index': '22',
#   'h_class': 'H'},
#  '49497916': {'corpus_author_id': '49497916',
#   'name': 'Ana Miriam Clemades Méndez',
#   'num_citations': '639',
#   'num_papers': '38',
#   'i10': '16',
#   'h_index': '12',
#   'h_class': 'H'},
#  '39834295': {'corpus_author_id': '39834295',
#   'name': 'Brian R. Copeland',
#   'num_citations': '1004',
#   'num_papers': '42',
#   'i10': '9',
#   'h_index': '9',
#   'h_class': 'L'},
#  '34930895': {'corpus_author_id': '34930895',
#   'name': 'Jørgen Bendix',
#   'num_citations': '820',
#   'num_papers': '14',
#   'i10': '8',
#   'h_index': '9',
#   'h_class': 'L'},
#  '3052691': {'corpus_author_id': '3052691',
#   'name': 'Stéphane Pascal Dufour',
#   'num_citations': '1502',
#   'num_papers': '138',
#   'i10': '22',
#   'h_index': '17',
#   'h_class': 'H'},
#  '145938212': {'corpus_author_id': '145938212',
#   'name': 'Hans Kamp',
#   'num_citations': '4654',
#   'num_papers': '133',
#   'i10': '39',
#   'h_index': '25',
#   'h_class': 'H'},
#  '96840766': {'corpus_author_id': '96840766',
#   'name': 'Roland Liemberger',
#   'num_citations': '245',
#   'num_papers': '22',
#   'i10': '6',
#   'h_index': '7',
#   'h_class': 'L'},
#  '113091293': {'corpus_author_id': '113091293',
#   'name': 'Giulio Bellizia',
#   'num_citations': '0',
#   'num_papers': '2',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '4031920': {'corpus_author_id': '4031920',
#   'name': 'Anthony M Heagerty',
#   'num_citations': '6658',
#   'num_papers': '382',
#   'i10': '115',
#   'h_index': '39',
#   'h_class': 'H'},
#  '4909767': {'corpus_author_id': '4909767',
#   'name': 'Alireza Esteghamati',
#   'num_citations': '4553',
#   'num_papers': '235',
#   'i10': '88',
#   'h_index': '30',
#   'h_class': 'H'},
#  '2368678': {'corpus_author_id': '2368678',
#   'name': 'Jozef Baruník',
#   'num_citations': '1233',
#   'num_papers': '86',
#   'i10': '19',
#   'h_index': '14',
#   'h_class': 'H'},
#  '1403359125': {'corpus_author_id': '1403359125',
#   'name': 'H. A. Lingstone',
#   'num_citations': '626',
#   'num_papers': '1',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '35136589': {'corpus_author_id': '35136589',
#   'name': 'Chun-liang Lei',
#   'num_citations': '1152',
#   'num_papers': '24',
#   'i10': '2',
#   'h_index': '4',
#   'h_class': 'L'},
#  '1843755': {'corpus_author_id': '1843755',
#   'name': 'Catherine Longworth',
#   'num_citations': '24',
#   'num_papers': '6',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '97737745': {'corpus_author_id': '97737745',
#   'name': 'Barry A. Colbert',
#   'num_citations': '499',
#   'num_papers': '12',
#   'i10': '6',
#   'h_index': '6',
#   'h_class': 'L'},
#  '144420297': {'corpus_author_id': '144420297',
#   'name': 'C Michael Gibson',
#   'num_citations': '24145',
#   'num_papers': '672',
#   'i10': '297',
#   'h_index': '73',
#   'h_class': 'H'},
#  '103194076': {'corpus_author_id': '103194076',
#   'name': 'Carol Surprenant',
#   'num_citations': '1761',
#   'num_papers': '7',
#   'i10': '5',
#   'h_index': '7',
#   'h_class': 'L'},
#  '51915749': {'corpus_author_id': '51915749',
#   'name': 'W. Zhu Y. Bai',
#   'num_citations': '2',
#   'num_papers': '3',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '4374512': {'corpus_author_id': '4374512',
#   'name': 'Shireen Abdelgawad Hafez',
#   'num_citations': '209',
#   'num_papers': '29',
#   'i10': '3',
#   'h_index': '6',
#   'h_class': 'L'},
#  '152584223': {'corpus_author_id': '152584223',
#   'name': 'Paul Lujan',
#   'num_citations': '5355',
#   'num_papers': '516',
#   'i10': '115',
#   'h_index': '34',
#   'h_class': 'H'},
#  '8554944': {'corpus_author_id': '8554944',
#   'name': 'Kuan-Pin Su',
#   'num_citations': '2579',
#   'num_papers': '158',
#   'i10': '50',
#   'h_index': '25',
#   'h_class': 'H'},
#  '40517469': {'corpus_author_id': '40517469',
#   'name': 'Gerard Pauley',
#   'num_citations': '92',
#   'num_papers': '6',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '1483742117': {'corpus_author_id': '1483742117',
#   'name': 'عروة الزعبي',
#   'num_citations': '0',
#   'num_papers': '1',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '1394815101': {'corpus_author_id': '1394815101',
#   'name': 'JohnnyU.V. Monu',
#   'num_citations': '522',
#   'num_papers': '2',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '153594364': {'corpus_author_id': '153594364',
#   'name': 'J. C. Maureira',
#   'num_citations': '44',
#   'num_papers': '17',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '4010399': {'corpus_author_id': '4010399',
#   'name': 'Michael W. Eysenck',
#   'num_citations': '9328',
#   'num_papers': '259',
#   'i10': '103',
#   'h_index': '38',
#   'h_class': 'H'},
#  '145974626': {'corpus_author_id': '145974626',
#   'name': 'Gray A. Williams',
#   'num_citations': '1902',
#   'num_papers': '212',
#   'i10': '63',
#   'h_index': '23',
#   'h_class': 'H'},
#  '34634934': {'corpus_author_id': '34634934',
#   'name': 'Michael Bibby',
#   'num_citations': '208',
#   'num_papers': '19',
#   'i10': '5',
#   'h_index': '6',
#   'h_class': 'L'},
#  '33345159': {'corpus_author_id': '33345159',
#   'name': 'Paul Robin Krugman',
#   'num_citations': '25848',
#   'num_papers': '321',
#   'i10': '140',
#   'h_index': '73',
#   'h_class': 'H'},
#  '49394649': {'corpus_author_id': '49394649',
#   'name': 'Jian Xu',
#   'num_citations': '961',
#   'num_papers': '87',
#   'i10': '21',
#   'h_index': '15',
#   'h_class': 'H'},
#  '30940651': {'corpus_author_id': '30940651',
#   'name': 'Alihossein Sepahvand',
#   'num_citations': '148',
#   'num_papers': '20',
#   'i10': '7',
#   'h_index': '9',
#   'h_class': 'L'},
#  '32245455': {'corpus_author_id': '32245455',
#   'name': 'Rodrigo de Brito Cordeiro',
#   'num_citations': '11',
#   'num_papers': '3',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '94499484': {'corpus_author_id': '94499484',
#   'name': 'Jeffrey Kimball',
#   'num_citations': '47',
#   'num_papers': '20',
#   'i10': '1',
#   'h_index': '4',
#   'h_class': 'L'},
#  '96265332': {'corpus_author_id': '96265332',
#   'name': 'Alice Magnani',
#   'num_citations': '2855',
#   'num_papers': '323',
#   'i10': '71',
#   'h_index': '24',
#   'h_class': 'H'},
#  '12012463': {'corpus_author_id': '12012463',
#   'name': 'Ronald V. Clarke',
#   'num_citations': '4243',
#   'num_papers': '155',
#   'i10': '57',
#   'h_index': '29',
#   'h_class': 'H'},
#  '153526175': {'corpus_author_id': '153526175',
#   'name': 'G Bolan',
#   'num_citations': '77',
#   'num_papers': '8',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '3805042': {'corpus_author_id': '3805042',
#   'name': 'William J. Bellini',
#   'num_citations': '11358',
#   'num_papers': '268',
#   'i10': '176',
#   'h_index': '50',
#   'h_class': 'H'},
#  '49475470': {'corpus_author_id': '49475470',
#   'name': 'Arielle R. Rosenberg',
#   'num_citations': '943',
#   'num_papers': '61',
#   'i10': '24',
#   'h_index': '17',
#   'h_class': 'H'},
#  '48190736': {'corpus_author_id': '48190736',
#   'name': 'Peter E. Peters',
#   'num_citations': '1859',
#   'num_papers': '327',
#   'i10': '41',
#   'h_index': '23',
#   'h_class': 'H'},
#  '47241039': {'corpus_author_id': '47241039',
#   'name': 'Elske de Kanter',
#   'num_citations': '182',
#   'num_papers': '5',
#   'i10': '3',
#   'h_index': '3',
#   'h_class': 'L'},
#  '4623141': {'corpus_author_id': '4623141',
#   'name': 'Joseph E. Stiglitz',
#   'num_citations': '19161',
#   'num_papers': '485',
#   'i10': '174',
#   'h_index': '57',
#   'h_class': 'H'},
#  '144756673': {'corpus_author_id': '144756673',
#   'name': 'Ying Xu',
#   'num_citations': '1414',
#   'num_papers': '213',
#   'i10': '44',
#   'h_index': '21',
#   'h_class': 'H'},
#  '90682604': {'corpus_author_id': '90682604',
#   'name': 'Yan Chen',
#   'num_citations': '117',
#   'num_papers': '27',
#   'i10': '3',
#   'h_index': '5',
#   'h_class': 'L'},
#  '153094035': {'corpus_author_id': '153094035',
#   'name': 'Ming Dong Zhou',
#   'num_citations': '384',
#   'num_papers': '19',
#   'i10': '10',
#   'h_index': '10',
#   'h_class': 'H'},
#  '39718117': {'corpus_author_id': '39718117',
#   'name': 'Michelle R. Molis',
#   'num_citations': '718',
#   'num_papers': '58',
#   'i10': '13',
#   'h_index': '13',
#   'h_class': 'H'},
#  '16221889': {'corpus_author_id': '16221889',
#   'name': 'Robert Arp',
#   'num_citations': '430',
#   'num_papers': '53',
#   'i10': '2',
#   'h_index': '6',
#   'h_class': 'L'},
#  '39017954': {'corpus_author_id': '39017954',
#   'name': 'Tolesa Bekele',
#   'num_citations': '3015',
#   'num_papers': '24',
#   'i10': '14',
#   'h_index': '13',
#   'h_class': 'H'},
#  '5287808': {'corpus_author_id': '5287808',
#   'name': 'Eleftherios P Mamounas',
#   'num_citations': '8895',
#   'num_papers': '169',
#   'i10': '70',
#   'h_index': '46',
#   'h_class': 'H'},
#  '50342135': {'corpus_author_id': '50342135',
#   'name': 'Shiyue Li',
#   'num_citations': '88',
#   'num_papers': '28',
#   'i10': '1',
#   'h_index': '6',
#   'h_class': 'L'},
#  '143713439': {'corpus_author_id': '143713439',
#   'name': 'James R. Cowie',
#   'num_citations': '768',
#   'num_papers': '81',
#   'i10': '16',
#   'h_index': '13',
#   'h_class': 'H'},
#  '144535266': {'corpus_author_id': '144535266',
#   'name': 'Teichert M Huang',
#   'num_citations': '433',
#   'num_papers': '2',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '70952562': {'corpus_author_id': '70952562',
#   'name': 'Technické V Brně',
#   'num_citations': '498',
#   'num_papers': '195',
#   'i10': '2',
#   'h_index': '4',
#   'h_class': 'L'},
#  '4545568': {'corpus_author_id': '4545568',
#   'name': 'Seung-Yul Lee',
#   'num_citations': '210',
#   'num_papers': '54',
#   'i10': '7',
#   'h_index': '9',
#   'h_class': 'L'},
#  '1720496': {'corpus_author_id': '1720496',
#   'name': 'Hang Chi',
#   'num_citations': '576',
#   'num_papers': '80',
#   'i10': '15',
#   'h_index': '12',
#   'h_class': 'H'},
#  '4289694': {'corpus_author_id': '4289694',
#   'name': 'Neil C Dodge',
#   'num_citations': '593',
#   'num_papers': '42',
#   'i10': '21',
#   'h_index': '17',
#   'h_class': 'H'},
#  '145410013': {'corpus_author_id': '145410013',
#   'name': 'John Elkington',
#   'num_citations': '1677',
#   'num_papers': '66',
#   'i10': '11',
#   'h_index': '11',
#   'h_class': 'H'},
#  '1718355': {'corpus_author_id': '1718355',
#   'name': 'Dong Liu',
#   'num_citations': '10651',
#   'num_papers': '1668',
#   'i10': '245',
#   'h_index': '42',
#   'h_class': 'H'},
#  '46438662': {'corpus_author_id': '46438662',
#   'name': 'Celia Roberts',
#   'num_citations': '1969',
#   'num_papers': '199',
#   'i10': '42',
#   'h_index': '25',
#   'h_class': 'H'},
#  '3549900': {'corpus_author_id': '3549900',
#   'name': 'Fangqiang Wei',
#   'num_citations': '207',
#   'num_papers': '12',
#   'i10': '2',
#   'h_index': '3',
#   'h_class': 'L'},
#  '50652037': {'corpus_author_id': '50652037',
#   'name': 'Ming Li',
#   'num_citations': '3492',
#   'num_papers': '128',
#   'i10': '43',
#   'h_index': '27',
#   'h_class': 'H'},
#  '47188169': {'corpus_author_id': '47188169',
#   'name': 'Raquel C. Marion',
#   'num_citations': '681',
#   'num_papers': '2',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '144831035': {'corpus_author_id': '144831035',
#   'name': 'Jong-Won Ha',
#   'num_citations': '1263',
#   'num_papers': '264',
#   'i10': '44',
#   'h_index': '20',
#   'h_class': 'H'},
#  '3603363': {'corpus_author_id': '3603363',
#   'name': 'Joan Cox Gill',
#   'num_citations': '2673',
#   'num_papers': '222',
#   'i10': '62',
#   'h_index': '28',
#   'h_class': 'H'},
#  '2125898': {'corpus_author_id': '2125898',
#   'name': 'Huilin Li',
#   'num_citations': '4765',
#   'num_papers': '144',
#   'i10': '71',
#   'h_index': '36',
#   'h_class': 'H'},
#  '3758099': {'corpus_author_id': '3758099',
#   'name': 'Suzy V. Torti',
#   'num_citations': '6806',
#   'num_papers': '176',
#   'i10': '90',
#   'h_index': '43',
#   'h_class': 'H'},
#  '1729096': {'corpus_author_id': '1729096',
#   'name': 'Juan Manuel Corchado',
#   'num_citations': '4624',
#   'num_papers': '666',
#   'i10': '142',
#   'h_index': '33',
#   'h_class': 'H'},
#  '119338865': {'corpus_author_id': '119338865',
#   'name': 'Uganda Land Alliance',
#   'num_citations': '78',
#   'num_papers': '3',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '49319257': {'corpus_author_id': '49319257',
#   'name': 'Razelle Kurzrock',
#   'num_citations': '24455',
#   'num_papers': '1270',
#   'i10': '499',
#   'h_index': '74',
#   'h_class': 'H'},
#  '152145276': {'corpus_author_id': '152145276',
#   'name': 'Robert James Hirosky',
#   'num_citations': '12210',
#   'num_papers': '1306',
#   'i10': '213',
#   'h_index': '43',
#   'h_class': 'H'},
#  '31234193': {'corpus_author_id': '31234193',
#   'name': 'Edric Gill',
#   'num_citations': '92',
#   'num_papers': '12',
#   'i10': '3',
#   'h_index': '4',
#   'h_class': 'L'},
#  '144748907': {'corpus_author_id': '144748907',
#   'name': 'Nicholas Steel',
#   'num_citations': '4660',
#   'num_papers': '104',
#   'i10': '29',
#   'h_index': '23',
#   'h_class': 'H'},
#  '2769326': {'corpus_author_id': '2769326',
#   'name': 'Steven Lowette',
#   'num_citations': '9531',
# ...
#  '3301920': {'corpus_author_id': '3301920',
#   'name': 'Un Yong Nahm',
#   'num_citations': '302',
#   'num_papers': '7',
#   'i10': '4',
#   'h_index': '5',
#   'h_class': 'L'},
#  '1382625683': {'corpus_author_id': '1382625683',
#   'name': 'Cédric Prieels',
#   'num_citations': '564',
#   'num_papers': '199',
#   'i10': '13',
#   'h_index': '12',
#   'h_class': 'H'},
#  '145346857': {'corpus_author_id': '145346857',
#   'name': 'Arne Bröring',
#   'num_citations': '1332',
#   'num_papers': '62',
#   'i10': '25',
#   'h_index': '20',
#   'h_class': 'H'},
#  '48764263': {'corpus_author_id': '48764263',
#   'name': 'A. P. Shcheglova',
#   'num_citations': '11',
#   'num_papers': '20',
#   'i10': '1',
#   'h_index': '1',
#   'h_class': 'L'},
#  '2072426': {'corpus_author_id': '2072426',
#   'name': 'Azeem Majeed',
#   'num_citations': '18449',
#   'num_papers': '703',
#   'i10': '299',
#   'h_index': '62',
#   'h_class': 'H'},
#  '4552817': {'corpus_author_id': '4552817',
#   'name': 'Mohammed M. Albarrak',
#   'num_citations': '280',
#   'num_papers': '9',
#   'i10': '4',
#   'h_index': '5',
#   'h_class': 'L'},
#  '46292092': {'corpus_author_id': '46292092',
#   'name': 'Laura H Gunn',
#   'num_citations': '208',
#   'num_papers': '22',
#   'i10': '7',
#   'h_index': '8',
#   'h_class': 'L'},
#  '144715977': {'corpus_author_id': '144715977',
#   'name': 'Kovin Naidoo',
#   'num_citations': '6633',
#   'num_papers': '80',
#   'i10': '43',
#   'h_index': '27',
#   'h_class': 'H'},
#  '35443469': {'corpus_author_id': '35443469',
#   'name': 'Alan E. Fryer',
#   'num_citations': '1206',
#   'num_papers': '66',
#   'i10': '22',
#   'h_index': '16',
#   'h_class': 'H'},
#  '104225051': {'corpus_author_id': '104225051',
#   'name': 'Claudia-elisabeth Wulz',
#   'num_citations': '6261',
#   'num_papers': '455',
#   'i10': '68',
#   'h_index': '25',
#   'h_class': 'H'},
#  '145478688': {'corpus_author_id': '145478688',
#   'name': 'Charles R. Newton',
#   'num_citations': '5089',
#   'num_papers': '121',
#   'i10': '59',
#   'h_index': '31',
#   'h_class': 'H'},
#  '48564247': {'corpus_author_id': '48564247',
#   'name': 'Martin Czub',
#   'num_citations': '1133',
#   'num_papers': '6',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '47933934': {'corpus_author_id': '47933934',
#   'name': 'Sylvain Baize',
#   'num_citations': '1098',
#   'num_papers': '14',
#   'i10': '5',
#   'h_index': '7',
#   'h_class': 'L'},
#  '144306548': {'corpus_author_id': '144306548',
#   'name': 'Stéphane Laurent',
#   'num_citations': '20024',
#   'num_papers': '471',
#   'i10': '154',
#   'h_index': '57',
#   'h_class': 'H'},
#  '26952440': {'corpus_author_id': '26952440',
#   'name': 'Gil Keren',
#   'num_citations': '136',
#   'num_papers': '20',
#   'i10': '4',
#   'h_index': '7',
#   'h_class': 'L'},
#  '143917719': {'corpus_author_id': '143917719',
#   'name': 'V. A. Shvetsov',
#   'num_citations': '141',
#   'num_papers': '25',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '2309370': {'corpus_author_id': '2309370',
#   'name': 'Andrzej Więcek',
#   'num_citations': '1103',
#   'num_papers': '41',
#   'i10': '13',
#   'h_index': '11',
#   'h_class': 'H'},
#  '40408249': {'corpus_author_id': '40408249',
#   'name': 'Jun Qian',
#   'num_citations': '1550',
#   'num_papers': '51',
#   'i10': '12',
#   'h_index': '11',
#   'h_class': 'H'},
#  '152621331': {'corpus_author_id': '152621331',
#   'name': 'Yi Zhao',
#   'num_citations': '46',
#   'num_papers': '6',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '40995293': {'corpus_author_id': '40995293',
#   'name': 'Krishna Mohan Medicherla',
#   'num_citations': '16',
#   'num_papers': '23',
#   'i10': '0',
#   'h_index': '3',
#   'h_class': 'L'},
#  '143976087': {'corpus_author_id': '143976087',
#   'name': 'Peter Clark',
#   'num_citations': '5138',
#   'num_papers': '293',
#   'i10': '76',
#   'h_index': '36',
#   'h_class': 'H'},
#  '46519813': {'corpus_author_id': '46519813',
#   'name': 'Michael Zheng Song',
#   'num_citations': '2316',
#   'num_papers': '75',
#   'i10': '26',
#   'h_index': '20',
#   'h_class': 'H'},
#  '5355429': {'corpus_author_id': '5355429',
#   'name': 'Jürg M Sommer',
#   'num_citations': '1135',
#   'num_papers': '8',
#   'i10': '6',
#   'h_index': '6',
#   'h_class': 'L'},
#  '40155003': {'corpus_author_id': '40155003',
#   'name': 'Andrew S. Dunn',
#   'num_citations': '2601',
#   'num_papers': '78',
#   'i10': '24',
#   'h_index': '16',
#   'h_class': 'H'},
#  '152706451': {'corpus_author_id': '152706451',
#   'name': 'Mark Allen',
#   'num_citations': '339',
#   'num_papers': '9',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '4319823': {'corpus_author_id': '4319823',
#   'name': 'Francis A. Plummer',
#   'num_citations': '7639',
#   'num_papers': '215',
#   'i10': '127',
#   'h_index': '47',
#   'h_class': 'H'},
#  '30449581': {'corpus_author_id': '30449581',
#   'name': 'Weishun Lan',
#   'num_citations': '26',
#   'num_papers': '4',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '1838575': {'corpus_author_id': '1838575',
#   'name': 'Sang-Chul Lee',
#   'num_citations': '619',
#   'num_papers': '92',
#   'i10': '12',
#   'h_index': '11',
#   'h_class': 'H'},
#  '6000858': {'corpus_author_id': '6000858',
#   'name': 'Seung-Woo Cho',
#   'num_citations': '2539',
#   'num_papers': '195',
#   'i10': '62',
#   'h_index': '27',
#   'h_class': 'H'},
#  '3682261': {'corpus_author_id': '3682261',
#   'name': 'A. I. J. Brain',
#   'num_citations': '1386',
#   'num_papers': '62',
#   'i10': '18',
#   'h_index': '15',
#   'h_class': 'H'},
#  '13651729': {'corpus_author_id': '13651729',
#   'name': 'Edouard Coupet',
#   'num_citations': '1',
#   'num_papers': '5',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '4773439': {'corpus_author_id': '4773439',
#   'name': 'Wanling Xie',
#   'num_citations': '210',
#   'num_papers': '8',
#   'i10': '4',
#   'h_index': '4',
#   'h_class': 'L'},
#  '5641934': {'corpus_author_id': '5641934',
#   'name': 'Danlin Fan',
#   'num_citations': '5437',
#   'num_papers': '30',
#   'i10': '22',
#   'h_index': '22',
#   'h_class': 'H'},
#  '5244668': {'corpus_author_id': '5244668',
#   'name': 'Teris Cheung',
#   'num_citations': '274',
#   'num_papers': '27',
#   'i10': '6',
#   'h_index': '8',
#   'h_class': 'L'},
#  '145613058': {'corpus_author_id': '145613058',
#   'name': 'André G. Uitterlinden',
#   'num_citations': '73501',
#   'num_papers': '1198',
#   'i10': '688',
#   'h_index': '130',
#   'h_class': 'H'},
#  '8017367': {'corpus_author_id': '8017367',
#   'name': 'Nikolaos Tsilimparis',
#   'num_citations': '2402',
#   'num_papers': '241',
#   'i10': '30',
#   'h_index': '18',
#   'h_class': 'H'},
#  '8142683': {'corpus_author_id': '8142683',
#   'name': 'Zoltán Dörnyei',
#   'num_citations': '15409',
#   'num_papers': '163',
#   'i10': '86',
#   'h_index': '51',
#   'h_class': 'H'},
#  '143979395': {'corpus_author_id': '143979395',
#   'name': 'Harry Wechsler',
#   'num_citations': '9144',
#   'num_papers': '325',
#   'i10': '94',
#   'h_index': '40',
#   'h_class': 'H'},
#  '35154038': {'corpus_author_id': '35154038',
#   'name': 'Dávid Takács',
#   'num_citations': '564',
#   'num_papers': '32',
#   'i10': '6',
#   'h_index': '7',
#   'h_class': 'L'},
#  '2598044': {'corpus_author_id': '2598044',
#   'name': 'Monika Słowińska',
#   'num_citations': '647',
#   'num_papers': '64',
#   'i10': '17',
#   'h_index': '13',
#   'h_class': 'H'},
#  '2414800': {'corpus_author_id': '2414800',
#   'name': 'Elena Pirogova',
#   'num_citations': '64',
#   'num_papers': '16',
#   'i10': '2',
#   'h_index': '6',
#   'h_class': 'L'},
#  '7173859': {'corpus_author_id': '7173859',
#   'name': 'Katsumi Oshitani',
#   'num_citations': '39',
#   'num_papers': '14',
#   'i10': '3',
#   'h_index': '3',
#   'h_class': 'L'},
#  '145830795': {'corpus_author_id': '145830795',
#   'name': 'Henri Bachacou',
#   'num_citations': '13874',
#   'num_papers': '1319',
#   'i10': '270',
#   'h_index': '50',
#   'h_class': 'H'},
#  '1390117735': {'corpus_author_id': '1390117735',
#   'name': 'Carolina Pérez-Ferrer',
#   'num_citations': '6',
#   'num_papers': '4',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '5936974': {'corpus_author_id': '5936974',
#   'name': 'Clara C. Posthuma',
#   'num_citations': '917',
#   'num_papers': '41',
#   'i10': '19',
#   'h_index': '17',
#   'h_class': 'H'},
#  '2761526': {'corpus_author_id': '2761526',
#   'name': 'Imen Grida Ben Yahia',
#   'num_citations': '221',
#   'num_papers': '46',
#   'i10': '7',
#   'h_index': '9',
#   'h_class': 'L'},
#  '40523159': {'corpus_author_id': '40523159',
#   'name': 'Brent R. Yates',
#   'num_citations': '2234',
#   'num_papers': '360',
#   'i10': '60',
#   'h_index': '22',
#   'h_class': 'H'},
#  '31890417': {'corpus_author_id': '31890417',
#   'name': 'Qi Chen',
#   'num_citations': '1654',
#   'num_papers': '92',
#   'i10': '29',
#   'h_index': '19',
#   'h_class': 'H'},
#  '48088307': {'corpus_author_id': '48088307',
#   'name': 'Anna M Butcher',
#   'num_citations': '36',
#   'num_papers': '4',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '144216213': {'corpus_author_id': '144216213',
#   'name': 'Arthur W. Westerberg',
#   'num_citations': '1823',
#   'num_papers': '172',
#   'i10': '52',
#   'h_index': '20',
#   'h_class': 'H'},
#  '122065791': {'corpus_author_id': '122065791',
#   'name': 'M Mckee',
#   'num_citations': '8484',
#   'num_papers': '108',
#   'i10': '51',
#   'h_index': '32',
#   'h_class': 'H'},
#  '5892532': {'corpus_author_id': '5892532',
#   'name': 'Françoise Corbineau',
#   'num_citations': '3308',
#   'num_papers': '154',
#   'i10': '75',
#   'h_index': '30',
#   'h_class': 'H'},
#  '5354631': {'corpus_author_id': '5354631',
#   'name': 'Yitzhak Hadar',
#   'num_citations': '5533',
#   'num_papers': '264',
#   'i10': '140',
#   'h_index': '41',
#   'h_class': 'H'},
#  '32175359': {'corpus_author_id': '32175359',
#   'name': 'Kurtis Keller',
#   'num_citations': '919',
#   'num_papers': '28',
#   'i10': '14',
#   'h_index': '13',
#   'h_class': 'H'},
#  '121363443': {'corpus_author_id': '121363443',
#   'name': 'Jamie Burton',
#   'num_citations': '350',
#   'num_papers': '91',
#   'i10': '12',
#   'h_index': '11',
#   'h_class': 'H'},
#  '1707453': {'corpus_author_id': '1707453',
#   'name': 'Kenneth P. Birman',
#   'num_citations': '10704',
#   'num_papers': '332',
#   'i10': '135',
#   'h_index': '41',
#   'h_class': 'H'},
#  '6127419': {'corpus_author_id': '6127419',
#   'name': 'Joel N Maslow',
#   'num_citations': '2183',
#   'num_papers': '110',
#   'i10': '49',
#   'h_index': '24',
#   'h_class': 'H'},
#  '90129618': {'corpus_author_id': '90129618',
#   'name': 'Heribert Hiller',
#   'num_citations': '865',
#   'num_papers': '29',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '25302860': {'corpus_author_id': '25302860',
#   'name': 'Deborah L. Wheeler',
#   'num_citations': '386',
#   'num_papers': '59',
#   'i10': '12',
#   'h_index': '11',
#   'h_class': 'H'},
#  '2913159': {'corpus_author_id': '2913159',
#   'name': 'Robert B. Doorenbos',
#   'num_citations': '1592',
#   'num_papers': '13',
#   'i10': '8',
#   'h_index': '9',
#   'h_class': 'L'},
#  '47800762': {'corpus_author_id': '47800762',
#   'name': 'Svenja Nicolin Bolten',
#   'num_citations': '22',
#   'num_papers': '6',
#   'i10': '1',
#   'h_index': '2',
#   'h_class': 'L'},
#  '3675961': {'corpus_author_id': '3675961',
#   'name': 'Elizabeth H. Morrison',
#   'num_citations': '733',
#   'num_papers': '67',
#   'i10': '18',
#   'h_index': '15',
#   'h_class': 'H'},
#  '3951396': {'corpus_author_id': '3951396',
#   'name': 'Ulrich Goerlach',
#   'num_citations': '8553',
#   'num_papers': '1117',
#   'i10': '235',
#   'h_index': '41',
#   'h_class': 'H'},
#  '49341124': {'corpus_author_id': '49341124',
#   'name': 'Nancy Greenberg',
#   'num_citations': '275',
#   'num_papers': '22',
#   'i10': '5',
#   'h_index': '6',
#   'h_class': 'L'},
#  '4494046': {'corpus_author_id': '4494046',
#   'name': 'Seth Moortgat',
#   'num_citations': '3037',
#   'num_papers': '622',
#   'i10': '103',
#   'h_index': '26',
#   'h_class': 'H'},
#  '153912461': {'corpus_author_id': '153912461',
#   'name': 'Ken Takahashi',
#   'num_citations': '4469',
#   'num_papers': '16',
#   'i10': '9',
#   'h_index': '9',
#   'h_class': 'L'},
#  '48679770': {'corpus_author_id': '48679770',
#   'name': 'Catherine Huraux',
#   'num_citations': '251',
#   'num_papers': '9',
#   'i10': '2',
#   'h_index': '3',
#   'h_class': 'L'},
#  '144689887': {'corpus_author_id': '144689887',
#   'name': 'Adam Pease',
#   'num_citations': '2906',
#   'num_papers': '79',
#   'i10': '28',
#   'h_index': '19',
#   'h_class': 'H'},
#  '51118402': {'corpus_author_id': '51118402',
#   'name': 'Jianjun Liu',
#   'num_citations': '568',
#   'num_papers': '127',
#   'i10': '11',
#   'h_index': '11',
#   'h_class': 'H'},
#  '34876963': {'corpus_author_id': '34876963',
#   'name': 'Ariana Wyatt',
#   'num_citations': '7',
#   'num_papers': '3',
#   'i10': '0',
#   'h_index': '2',
#   'h_class': 'L'},
#  '145366815': {'corpus_author_id': '145366815',
#   'name': 'James J. Buckley',
#   'num_citations': '4552',
#   'num_papers': '456',
#   'i10': '80',
#   'h_index': '36',
#   'h_class': 'H'},
#  '34751114': {'corpus_author_id': '34751114',
#   'name': 'Chengnian Sun',
#   'num_citations': '1224',
#   'num_papers': '34',
#   'i10': '22',
#   'h_index': '16',
#   'h_class': 'H'},
#  '103411727': {'corpus_author_id': '103411727',
#   'name': 'Joseph Boudreau',
#   'num_citations': '12800',
#   'num_papers': '1352',
#   'i10': '261',
#   'h_index': '46',
#   'h_class': 'H'},
#  '49213346': {'corpus_author_id': '49213346',
#   'name': 'Catherine B. Woods',
#   'num_citations': '349',
#   'num_papers': '17',
#   'i10': '10',
#   'h_index': '10',
#   'h_class': 'H'},
#  '49239080': {'corpus_author_id': '49239080',
#   'name': 'Eliska Prochazkova',
#   'num_citations': '68',
#   'num_papers': '13',
#   'i10': '3',
#   'h_index': '3',
#   'h_class': 'L'},
#  '3115364': {'corpus_author_id': '3115364',
#   'name': 'Pablo A. Estévez',
#   'num_citations': '1543',
#   'num_papers': '127',
#   'i10': '29',
#   'h_index': '18',
#   'h_class': 'H'},
#  '49448708': {'corpus_author_id': '49448708',
#   'name': 'Sivaramaiah Nallapeta',
#   'num_citations': '19',
#   'num_papers': '8',
#   'i10': '1',
#   'h_index': '3',
#   'h_class': 'L'},
#  '152575253': {'corpus_author_id': '152575253',
#   'name': 'Jacob Linacre',
#   'num_citations': '5556',
#   'num_papers': '737',
#   'i10': '112',
#   'h_index': '35',
#   'h_class': 'H'},
#  '145366818': {'corpus_author_id': '145366818',
#   'name': 'Jorunn Jacobsen Buckley',
#   'num_citations': '64',
#   'num_papers': '75',
#   'i10': '1',
#   'h_index': '4',
#   'h_class': 'L'},
#  '123819740': {'corpus_author_id': '123819740',
#   'name': 'Qamar Hassan',
#   'num_citations': '4634',
#   'num_papers': '506',
#   'i10': '100',
#   'h_index': '30',
#   'h_class': 'H'},
#  '2118285': {'corpus_author_id': '2118285',
#   'name': 'Paolo Buono',
#   'num_citations': '974',
#   'num_papers': '98',
#   'i10': '21',
#   'h_index': '16',
#   'h_class': 'H'},
#  '49104216': {'corpus_author_id': '49104216',
#   'name': 'Kai Jia',
#   'num_citations': '1330',
#   'num_papers': '15',
#   'i10': '2',
#   'h_index': '5',
#   'h_class': 'L'},
#  '46411340': {'corpus_author_id': '46411340',
#   'name': 'Francesco Romeo',
#   'num_citations': '5204',
#   'num_papers': '604',
#   'i10': '119',
#   'h_index': '31',
#   'h_class': 'H'},
#  '47458428': {'corpus_author_id': '47458428',
#   'name': 'Stephen Fuller . Austin',
#   'num_citations': '174',
#   'num_papers': '131',
#   'i10': '5',
#   'h_index': '6',
#   'h_class': 'L'},
#  '38324588': {'corpus_author_id': '38324588',
#   'name': 'Chao Wang',
#   'num_citations': '1305',
#   'num_papers': '197',
#   'i10': '41',
#   'h_index': '20',
#   'h_class': 'H'},
#  '4300841': {'corpus_author_id': '4300841',
#   'name': 'Rebecca F Grais',
#   'num_citations': '4036',
#   'num_papers': '222',
#   'i10': '95',
#   'h_index': '36',
#   'h_class': 'H'},
#  '50333318': {'corpus_author_id': '50333318',
#   'name': 'Paolo Gunnellini',
#   'num_citations': '4458',
#   'num_papers': '573',
#   'i10': '105',
#   'h_index': '30',
#   'h_class': 'H'},
#  '4029220': {'corpus_author_id': '4029220',
#   'name': 'Louis M Mansky',
#   'num_citations': '3235',
#   'num_papers': '121',
#   'i10': '64',
#   'h_index': '28',
#   'h_class': 'H'},
#  '16167220': {'corpus_author_id': '16167220',
#   'name': 'Fewzia Atik Bekkara',
#   'num_citations': '86',
#   'num_papers': '12',
#   'i10': '3',
#   'h_index': '5',
#   'h_class': 'L'},
#  '120173074': {'corpus_author_id': '120173074',
#   'name': 'مدوار سهام مدوار سهام',
#   'num_citations': '0',
#   'num_papers': '1',
#   'i10': '0',
#   'h_index': '1',
#   'h_class': 'L'},
#  '35277226': {'corpus_author_id': '35277226',
#   'name': 'Mathieu Herman',
#   'num_citations': '1279',
#   'num_papers': '20',
#   'i10': '12',
#   'h_index': '12',
#   'h_class': 'H'},
#  ...}

# %%
[aid for aid,author in authors.items() if author['num_papers'] =='10011']
# Out:
# ['1393846726']

# %%
authors['1393846726']
# Out:
# {'corpus_author_id': '1393846726',
#  'name': '\xa0 \xa0 \xa0',
#  'num_citations': '2052',
#  'num_papers': '10011',
#  'i10': '6',
#  'h_index': '8',
#  'h_class': 'L'}

# %%
print ("Number of papers:", len(papers))
print ("Min Year:", min([float(p['paper_year']) for p in papers.values() if p['paper_year'] != '']))
print ("Common venues:", Counter([p['venue'] for p in papers.values()]).most_common(10))
# Out:
# Number of papers: 8879
# Min Year: 1824.0
# Common venues: [('', 4601), ('ArXiv', 96), ('Nature', 59), ('The Lancet', 59), ('The New England journal of medicine', 53), ('Science', 44), ('medRxiv', 37), ('Proceedings of the National Academy of Sciences of the United States of America', 34), ('JAMA', 27), ('Sensors', 23)]

# %%
print ("Number of queries:", len(training_data))
print ("Common queries:", Counter([p['query'] for p in training_data]).most_common(10))
# Out:
# Number of queries: 200
# Common queries: [('cloud computing', 1), ('constitutional law', 1), ('metalinguistic knowledge', 1), ('drogenzubereitung', 1), ('usefulness of debit card', 1), ('facilities management', 1), ('cloud computing in education', 1), ('consumer buying behaviour in branded and unbranded clothing', 1), ('python', 1), ('participatory culture', 1)]

# %%
# %matplotlib inline
from matplotlib import colors
import random

fig, axs = plt.subplots(1, 2, tight_layout=True)
n_bins = 25

#authors = dict(random.sample(authors.items(), 5000)) # Random Sampling
# fracs = N / N.max()
# norm = colors.Normalize(fracs.min(), fracs.max())

N, bins, patches = axs[0].hist([authors[x]["num_citations"] for x in authors] , bins=n_bins)
fracs = N / N.max()
norm = colors.Normalize(fracs.min(), fracs.max())
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

N, bins, patches = axs[1].hist([authors[x]["num_papers"] for x in authors] , bins=n_bins)
fracs = N / N.max()
norm = colors.Normalize(fracs.min(), fracs.max())
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

axs[0].title.set_text('Citation Distribution')
axs[1].title.set_text('Paper Distribution')

plt.show()

# %% [markdown]
# # Calculate the communities from the graph

# %%
import community as community_louvain
partion_papers = community_louvain.best_partition(G_papers)
partion_authors = community_louvain.best_partition(G_authors)

# %%
G_papers.number_of_nodes()
# Out:
# 2623334

# %%
G_authors.number_of_nodes()
# Out:
# 29733

# %%
query_id = 0
print ("comunities of authors for the query:", training_data[query_id]['query'])
for d in training_data[query_id]['documents']:
    if d['doc_id'] in papers:
        curr_partition = set()
        for author in papers[d['doc_id']]['authors_order']:
            if author[0] in partion_authors:
                curr_partition.add(partion_authors[author[0]])
        print (list(curr_partition), d['relevance'])
# Out:
# comunities of authors for the query: cloud computing
# [4211] 0
# [1917] 0
# [3430] 0
# [1007] 0
# [4129] 1
# [1007] 0
# [] 0
# [3812] 0
# [381] 0
# [2393] 0
# [1007] 0
# [3971] 0
# [2600] 0
# [] 1
# [4716] 0
# [267] 0
# [1520] 0
# [2107] 0
# [1007] 0
# [1007] 0
# [3647] 0
# [85] 0
# [3354] 0
# [] 0
# [3565] 0
# [2029] 0
# [1520] 0
# [428] 0
# [1382] 1
# [2600] 0

# %%
query_id = 1
print ("comunities of papers for the query:", training_data[query_id]['query'])
for d in training_data[query_id]['documents']:
    if d['doc_id'] in partion_papers:
        print (partion_papers[d['doc_id']], d['relevance'])
# Out:
# comunities of papers for the query: constitutional law
# 51 0
# 66 0
# 47 0
# 11 0
# 9 0
# 50 0
# 123 1
# 47 0
# 74 0
# 51 0
# 123 0
# 51 0
# 59 0
# 52 0
# 56 1
# 52 0
# 123 0
# 11 0
# 32 0
# 47 0
# 12 1
# 52 0
# 123 1
# 123 0
# 47 0
# 123 0
# 51 0
# 567 0
# 47 1
# 123 0

# %% [markdown]
# TODO: look the relevant items in the queries and compute co-occurence of the communities. Then, use this information to rerank the results.
