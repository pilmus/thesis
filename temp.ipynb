# %%
import pandas as pd

# %%
pred = pd.read_csv('predictions-lambdamart-ferraro-test-sequence.csv')

# %%
predsort = pred.sort_values(by=['sid','pred'])

# %%
prlist_df = predsort.groupby('sid').pred.apply(list).reset_index(name='pred_list')

# %%
prlist_df
# Out:
#     sid                                          pred_list
# 0     0  [-0.07448685647391573, -0.05188655612989922, 0...
# 1     1  [-0.49842682202064, -0.17805973566505184, 0.05...
# 2     2  [-0.36823033997215465, -0.3560634211999737, -0...
# 3     3  [-0.4448644060248458, -0.4378880191911314, -0....
# 4     4  [-0.020409248320924715, 0.008953953397480705, ...
# 5     5  [-0.3589724011827904, -0.09610833572461196, 0....
# 6     6  [-0.3731603791484235, -0.13142646719996898, -0...
# 7     7  [-0.4192521220071137, -0.3806995004954382, -0....
# 8     8  [-0.4575879007481292, -0.4569288198023032, -0....
# 9     9  [-0.4309696749671499, -0.4002062447662692, -0....
# 10   10  [-0.4366712247529749, -0.4286919047581754, -0....

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
predsort
# Out:
#      sid  q_num                                    doc_id      pred
# 128    0      0  dff096df325b4b1022c0ec4b5abd1b0ddaa7b304 -0.074487
# 129    0      0  34ba4f3d2a38b88153308f2a7f12651b440f5812 -0.051887
# 124    0      0  4a1472c575488ed9acee6c5481f68b95a0c34092  0.065183
# 131    0      0  efe0b6115d460fcd2173fc04d113694f1ded8692  0.065183
# 132    0      0  40d8bea494d4ff4c46f7ad5cb2dcdaa6f96ed5a4  0.138348
# ..   ...    ...                                       ...       ...
# 183   10      0  793d1f240cc08e4a1121ca58de3d2f6f07f02b8a  0.088214
# 224   10      0  e88baf82f374547c5c604e0d643144efcd004cef  0.105380
# 148   10      0  02acadc977b89238cab44c8e5839a70de1e451d3  0.126241
# 137   10      0  0c158d348dbc0573f0ca724dd818d35d6c17820a  0.133608
# 143   10      0  73e81f0546ef0fd78e259c19b4e83dd69faa26ab  0.160796
#
# [245 rows x 4 columns]
